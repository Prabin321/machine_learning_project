# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading the dataset
df = pd.read_csv("../data/results.csv")

# %%
#viewing the first few random data
df.sample(10)
# Out:
#              date          home_team   away_team  home_score  away_score  \
# 6372   1965-07-25        Ivory Coast     Algeria         2.0         0.0
# 6249   1965-04-01             Mexico     Curaçao         5.0         0.0
# 10935  1977-03-26               Peru       Chile         2.0         0.0
# 34074  2010-09-07            Denmark     Iceland         1.0         0.0
# 38094  2014-09-10             Uganda      Guinea         2.0         0.0
# 18251  1992-05-24          Guatemala     Ecuador         1.0         1.0
# 25747  2001-07-01            Tunisia       Congo         6.0         0.0
# 9699   1974-03-31            Hungary    Bulgaria         3.0         1.0
# 26422  2002-05-21         San Marino     Estonia         0.0         1.0
# 41943  2018-10-13  Equatorial Guinea  Madagascar         0.0         1.0
#
#                                  tournament            city  \
# 6372                      All-African Games     Brazzaville
# ...

# %%
#Inspecting the shape of the dataset
df.shape #it gives the number of rows and columns in the format of (rows, columns)
# Out:
# (49477, 9)

# %%
#Identifying the name of columns in the dataset
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral'],
#       dtype='str')

# %%
#Checking for any null values in the dataset
df.isnull().sum() #It shows home_score and away_score has each 68 null values respectively which we need to handle
# Out:
# date           0
# home_team      0
# away_team      0
# home_score    68
# away_score    68
# tournament     0
# city           0
# country        0
# neutral        0
# dtype: int64

# %%
#Checking for the oldest and latest date ranges
print(df['date'].min())
print(df['date'].max())
# Out:
# 1872-11-30
# 2026-06-27

# %%
#Counting the total number of tournaments
df['tournament'].value_counts().head(10)
# Out:
# tournament
# Friendly                                18388
# FIFA World Cup qualification             8771
# UEFA Euro qualification                  2824
# African Cup of Nations qualification     2327
# FIFA World Cup                           1036
# Copa América                              869
# African Cup of Nations                    845
# AFC Asian Cup qualification               829
# UEFA Nations League                       658
# CECAFA Cup                                620
# Name: count, dtype: int64
